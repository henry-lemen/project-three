# %% [markdown]
# # explanation

# %%
import pandas as pd
from pathlib import Path
import datetime

# %%
file = Path("../data/traffic_crashes.csv")

# %%
crash_data_df = pd.read_csv(file)
crash_data_df.head()
# Out:
#                                      CRASH_RECORD_ID     RD_NO  \
# 0  012c5bfce715efb2f2b387d6dd86f9c13e9dc1809fb52a...  JG341943
# 1  01d457f032e23d935a0b8f6b4c88221375180ffd4cd959...  JG338388
# 2  02249b4747a4bf40b88a8357304a98dfeaef9c38eebbf0...  JG350008
# 3  03e3b6caad71b78ed9ae325648effa9512bfb2517aed30...  JG338049
# 4  0481fc919b38f1572d4ba04b069766102d904a662ff096...  JG338431
#
#   CRASH_DATE_EST_I              CRASH_DATE  POSTED_SPEED_LIMIT  \
# 0              NaN  07/12/2023 03:05:00 PM                  30
# 1              NaN  07/12/2023 05:50:00 PM                  30
# 2              NaN  07/12/2023 02:00:00 PM                  30
# 3              NaN  07/12/2023 07:05:00 AM                  30
# 4              NaN  07/12/2023 06:30:00 PM                  30
#
#   TRAFFIC_CONTROL_DEVICE DEVICE_CONDITION      WEATHER_CONDITION  \
# 0            NO CONTROLS      NO CONTROLS                  CLEAR
# 1            NO CONTROLS      NO CONTROLS                  CLEAR
# ...

# %%
cleaned_crash_data = crash_data_df[['RD_NO', 'CRASH_DATE', 'POSTED_SPEED_LIMIT', 'WEATHER_CONDITION', 'LIGHTING_CONDITION', 'FIRST_CRASH_TYPE', 'TRAFFICWAY_TYPE', 
                                    'ROADWAY_SURFACE_COND', 'ROAD_DEFECT', 'CRASH_TYPE', 'DAMAGE', 'PRIM_CONTRIBUTORY_CAUSE', 'SEC_CONTRIBUTORY_CAUSE', 'STREET_NAME', 
                                    'CRASH_HOUR', 'CRASH_DAY_OF_WEEK', 'CRASH_MONTH', 'LATITUDE', 'LONGITUDE', 'LOCATION']]
cleaned_crash_data.head()
# Out:
#       RD_NO              CRASH_DATE  POSTED_SPEED_LIMIT  \
# 0  JG341943  07/12/2023 03:05:00 PM                  30
# 1  JG338388  07/12/2023 05:50:00 PM                  30
# 2  JG350008  07/12/2023 02:00:00 PM                  30
# 3  JG338049  07/12/2023 07:05:00 AM                  30
# 4  JG338431  07/12/2023 06:30:00 PM                  30
#
#        WEATHER_CONDITION LIGHTING_CONDITION FIRST_CRASH_TYPE TRAFFICWAY_TYPE  \
# 0                  CLEAR           DAYLIGHT          TURNING     NOT DIVIDED
# 1                  CLEAR           DAYLIGHT         REAR END     NOT DIVIDED
# 2                  CLEAR           DAYLIGHT     OTHER OBJECT     NOT DIVIDED
# 3  FREEZING RAIN/DRIZZLE           DAYLIGHT         REAR END     NOT DIVIDED
# 4                  CLEAR           DAYLIGHT         REAR END     NOT DIVIDED
#
#   ROADWAY_SURFACE_COND ROAD_DEFECT              CRASH_TYPE         DAMAGE  \
# 0              UNKNOWN  NO DEFECTS  NO INJURY / DRIVE AWAY    OVER $1,500
# ...

# %%
cleaned_crash_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 746498 entries, 0 to 746497
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   RD_NO                    742191 non-null  object
#  1   CRASH_DATE               746498 non-null  object
#  2   POSTED_SPEED_LIMIT       746498 non-null  int64
#  3   WEATHER_CONDITION        746498 non-null  object
#  4   LIGHTING_CONDITION       746498 non-null  object
#  5   FIRST_CRASH_TYPE         746498 non-null  object
#  6   TRAFFICWAY_TYPE          746498 non-null  object
#  7   ROADWAY_SURFACE_COND     746498 non-null  object
#  8   ROAD_DEFECT              746498 non-null  object
#  9   CRASH_TYPE               746498 non-null  object
#  10  DAMAGE                   746498 non-null  object
#  11  PRIM_CONTRIBUTORY_CAUSE  746498 non-null  object
#  12  SEC_CONTRIBUTORY_CAUSE   746498 non-null  object
# ...

# %%
cleaned_df = cleaned_crash_data.dropna()
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 737324 entries, 0 to 746497
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   RD_NO                    737324 non-null  object
#  1   CRASH_DATE               737324 non-null  object
#  2   POSTED_SPEED_LIMIT       737324 non-null  int64
#  3   WEATHER_CONDITION        737324 non-null  object
#  4   LIGHTING_CONDITION       737324 non-null  object
#  5   FIRST_CRASH_TYPE         737324 non-null  object
#  6   TRAFFICWAY_TYPE          737324 non-null  object
#  7   ROADWAY_SURFACE_COND     737324 non-null  object
#  8   ROAD_DEFECT              737324 non-null  object
#  9   CRASH_TYPE               737324 non-null  object
#  10  DAMAGE                   737324 non-null  object
#  11  PRIM_CONTRIBUTORY_CAUSE  737324 non-null  object
#  12  SEC_CONTRIBUTORY_CAUSE   737324 non-null  object
# ...

# %%
cleaned_df['CRASH_DATE'] = pd.to_datetime(cleaned_df['CRASH_DATE'])
# Out:
# /var/folders/b_/47k771614dlgjd4cqk_f_y180000gn/T/ipykernel_14580/825383330.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   cleaned_df['CRASH_DATE'] = pd.to_datetime(cleaned_df['CRASH_DATE'])
# /var/folders/b_/47k771614dlgjd4cqk_f_y180000gn/T/ipykernel_14580/825383330.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df['CRASH_DATE'] = pd.to_datetime(cleaned_df['CRASH_DATE'])

# %%
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 737324 entries, 0 to 746497
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   RD_NO                    737324 non-null  object
#  1   CRASH_DATE               737324 non-null  datetime64[ns]
#  2   POSTED_SPEED_LIMIT       737324 non-null  int64
#  3   WEATHER_CONDITION        737324 non-null  object
#  4   LIGHTING_CONDITION       737324 non-null  object
#  5   FIRST_CRASH_TYPE         737324 non-null  object
#  6   TRAFFICWAY_TYPE          737324 non-null  object
#  7   ROADWAY_SURFACE_COND     737324 non-null  object
#  8   ROAD_DEFECT              737324 non-null  object
#  9   CRASH_TYPE               737324 non-null  object
#  10  DAMAGE                   737324 non-null  object
#  11  PRIM_CONTRIBUTORY_CAUSE  737324 non-null  object
#  12  SEC_CONTRIBUTORY_CAUSE   737324 non-null  object
# ...

# %%
selected_years = [2018, 2019, 2020, 2021, 2022]
final_df = cleaned_df[cleaned_df['CRASH_DATE'].dt.year.isin(selected_years)]
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 542189 entries, 5 to 746497
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   RD_NO                    542189 non-null  object
#  1   CRASH_DATE               542189 non-null  datetime64[ns]
#  2   POSTED_SPEED_LIMIT       542189 non-null  int64
#  3   WEATHER_CONDITION        542189 non-null  object
#  4   LIGHTING_CONDITION       542189 non-null  object
#  5   FIRST_CRASH_TYPE         542189 non-null  object
#  6   TRAFFICWAY_TYPE          542189 non-null  object
#  7   ROADWAY_SURFACE_COND     542189 non-null  object
#  8   ROAD_DEFECT              542189 non-null  object
#  9   CRASH_TYPE               542189 non-null  object
#  10  DAMAGE                   542189 non-null  object
#  11  PRIM_CONTRIBUTORY_CAUSE  542189 non-null  object
#  12  SEC_CONTRIBUTORY_CAUSE   542189 non-null  object
# ...

# %%
slim_df = final_df[['CRASH_DATE', 'POSTED_SPEED_LIMIT', 'WEATHER_CONDITION', 'LIGHTING_CONDITION', 'FIRST_CRASH_TYPE', 
                                    'ROADWAY_SURFACE_COND', 'ROAD_DEFECT', 'CRASH_TYPE', 'DAMAGE', 'PRIM_CONTRIBUTORY_CAUSE', 'SEC_CONTRIBUTORY_CAUSE', 'STREET_NAME', 
                                    'CRASH_HOUR', 'CRASH_DAY_OF_WEEK', 'CRASH_MONTH', 'LATITUDE', 'LONGITUDE']]
slim_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 542189 entries, 5 to 746497
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   CRASH_DATE               542189 non-null  datetime64[ns]
#  1   POSTED_SPEED_LIMIT       542189 non-null  int64
#  2   WEATHER_CONDITION        542189 non-null  object
#  3   LIGHTING_CONDITION       542189 non-null  object
#  4   FIRST_CRASH_TYPE         542189 non-null  object
#  5   ROADWAY_SURFACE_COND     542189 non-null  object
#  6   ROAD_DEFECT              542189 non-null  object
#  7   CRASH_TYPE               542189 non-null  object
#  8   DAMAGE                   542189 non-null  object
#  9   PRIM_CONTRIBUTORY_CAUSE  542189 non-null  object
#  10  SEC_CONTRIBUTORY_CAUSE   542189 non-null  object
#  11  STREET_NAME              542189 non-null  object
#  12  CRASH_HOUR               542189 non-null  int64
# ...

# %%
slim_df.to_csv('chicago_crash_data.csv', index=False, header=True)
